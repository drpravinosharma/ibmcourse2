# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Title: Peer Graded Assignment _Pravin Sharma

# %% [markdown]
# # Introduction
#
# This notebook provides an introduction to data science.

# %% [markdown]
# # Data Science languages:
#
# *  Python
# *  R
# *  Julia

# %% [markdown]
# # Data Science libraries:
#
# * Numpy
# * Pandas
# * Keras

# %% [markdown]
# | Data Science tools|
# | -------------------|
# |Jupyterlabs|
# |Anaconda|
# |Google colabs|

# %% [markdown]
# # Introducing arithmetic expression examples

# %%
# Multiplying numbers

a = 2
b = 5
c = a*b

print('The addition is ' +  str(c))


# Adding numbers
d = 2
e = 5
f = d*e

print("The multiplication is " + str(f))
# Out:
# The addition is 10
# The multiplication is 10

# %%
# Code to convert minutes to hours

# a is 200 minutes

a = 200

# Conversion of a into minutes is given by

b = (a/60)
print(b)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Objectives of the course:
#
# To introduce the languages of data science. Here various languages like R, Python were introduced.

# %% [markdown]
# ### Author
#
# Pravin Sharma
